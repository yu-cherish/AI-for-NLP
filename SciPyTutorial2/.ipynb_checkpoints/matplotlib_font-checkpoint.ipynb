# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 准备工作
#
# 1. 安装中文字体
# 2. 重建字体缓存
#
# ```python
# from matplotlib.font_manager import _rebuild; _rebuild()
# ```
# 3. 指定中文字体
#
# ```python
# import matplotlib as mpl
# mpl.rcParams['font.family'] = 'SimHei'
# mpl.rcParams['axes.unicode_minus']=False
# ```
#
# 4. 将字体文件设置放到配置文件[可选]

# %%
# 重建字体缓存
from matplotlib.font_manager import _rebuild; _rebuild()
# ~/.cache/matplotlib/fontlist-*.json

# %%
# 查找字体
from matplotlib import font_manager
font_manager.findfont('SimHei')

# find fonts in linux
# fc-list :lang=zh
# Out:
# '/Users/hlyang/Software/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %%
import matplotlib as mpl
mpl.rcParams['font.family'] = 'SimHei'
mpl.rcParams['axes.unicode_minus']=False

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 1000)
plt.plot(x, np.sin(x))
plt.xlabel("距离")
plt.ylabel("函数值")
plt.text(0.5, 0.5, "你好啊, 中文")
# Out:
# Text(0.5, 0.5, '你好啊, 中文')

# %% [markdown]
# ## 其他

# %% [markdown]
# ### 临时指定字体目录

# %%
import matplotlib as mpl
import matplotlib.font_manager as font_manager
# font_dirs = ['/System/Library/Fonts/', ]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)


from matplotlib import font_manager
font_manager.findfont('Songti')

# mpl.rcParams['font.family'] = 'SimHei'
# mpl.rcParams['axes.unicode_minus']=False
# Out:
# /Users/hlyang/Software/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Songti'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# '/Users/hlyang/Software/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %%
import matplotlib as mpl
mpl.get_configdir()
# Out:
# '/Users/hlyang/.matplotlib'

# %%
mpl.get_data_path()
# Out:
# '/Users/hlyang/Software/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data'

# %% [markdown]
# ### 直接指定字体路径

# %% [markdown]
# # 直接指定字体路径

# %%
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/System/Library/Fonts/PingFang.ttc',size=10)

x = np.linspace(-2*np.pi, 2*np.pi, 1000)
plt.plot(x, np.sin(x))
plt.xlabel("距离", fontproperties=font)
plt.ylabel("函数值", fontproperties=font)
plt.text(0.5, 0.5, "你好啊, 中文", fontproperties=font)
# Out:
# Text(0.5, 0.5, '你好啊, 中文')
